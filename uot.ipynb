# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.common.exceptions import NoSuchElementException
import time
import string
import openpyxl
import os
import json

# %%
PATH = ("C:\\Users\\fatih\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver = webdriver.Chrome(PATH)
# Out:
# <ipython-input-2-b6bf87c95fd0>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)

# %%
UoT= 'https://www.google.ca/maps/place/University+of+Toronto+-+St.+George+Campus/@43.6628917,-79.3978504,17z/data=!4m7!3m6!1s0x882b34b8f331fd9b:0x8d1d9bb6765a76f7!8m2!3d43.6628917!4d-79.3956564!9m1!1b1'
ReU= 'https://www.google.com/maps/place/Ryerson+University/@43.6576585,-79.3788017,17z/data=!4m7!3m6!1s0x89d4cb35431c1395:0xe8ed8bd69125d6f4!8m2!3d43.6576585!4d-79.3788017!9m1!1b1'
WeU= 'https://www.google.ca/maps/place/Western+University/@43.0095971,-81.2759223,17z/data=!4m7!3m6!1s0x882eee0e6ac42bd1:0xaa87f353aab9799b!8m2!3d43.0095971!4d-81.2737336!9m1!1b1'
UoO= 'https://www.google.ca/maps/place/University+of+Ottawa/@45.4231064,-75.6853216,17z/data=!4m7!3m6!1s0x4cce050a6db98d73:0x188a59c3622fdbae!8m2!3d45.4231064!4d-75.6831329!9m1!1b1'
YoU= 'https://www.google.ca/maps/place/York+University/@43.7734535,-79.5040571,17z/data=!4m7!3m6!1s0x89d4cd330b767bfb:0xdbb899cc9da76d19!8m2!3d43.7734535!4d-79.5018684!9m1!1b1'

# %%
#Opening Google maps url at a time & add sleeping duration to allow for full loading  
driver.get(UoT)
time.sleep(3)

# %%
#Creating a scrollable dynamic function to show all the reviews 
scrollable_div_UoT = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]')
for i in range(0,10):
    driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', scrollable_div_UoT)
    time.sleep(1)
# Out:
# <ipython-input-5-42e29cebd851>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   scrollable_div_UoT = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[2]')

# %%
import numpy as np
from Crypto.PublicKey import RSA
import json
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup as bs
import os 
import requests
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
# %matplotlib inline

# %%
#parsing the webpage
response_UoT = bs(driver.page_source, 'html.parser')
#closing the dirver after parsing it to start building and analysing the outcome
driver.close()

# %%
reviews_UoT = response_UoT.find_all('div', class_='ODSEW-ShBeI NIyLF-haAclf gm2-body-2')
len(reviews_UoT)
# Out:
# 100

# %%
# creating a review summary
# Select the items that will be used in the analysis
def get_review_summary(result_set):
    rev_dict = {'Review Rate': [], 'Review Time': [], 'Review Text': [], 'User': [], 'Impact': []}
    for result in result_set:
        review_rate = result.find('span', class_='ODSEW-ShBeI-H1e3jb')["aria-label"]
        review_time = result.find('span', class_='ODSEW-ShBeI-RgZmSc-date').text
        review_text = result.find('span', class_='ODSEW-ShBeI-text').text
        reviewer = result.find('div', class_='ODSEW-ShBeI-title').text
        Usefulness = result.find('div', class_='ODSEW-ShBeI-VdSJob').text
        rev_dict['Review Rate'].append(review_rate)
        rev_dict['Review Time'].append(review_time)
        rev_dict['Review Text'].append(review_text)
        rev_dict['User'].append(reviewer)
        rev_dict['Impact'].append(Usefulness)

    return(pd.DataFrame(rev_dict))

rev_summ = get_review_summary(reviews_UoT)
rev_summ
# Out:
#    Review Rate    Review Time  \
# 0     4 stars     a month ago
# 1     5 stars    7 months ago
# 2     5 stars    9 months ago
# 3     5 stars     3 weeks ago
# 4     5 stars    3 months ago
# ..         ...            ...
# 95    5 stars    2 months ago
# 96    5 stars      a year ago
# 97    5 stars      a year ago
# 98    3 stars      a year ago
# 99    2 stars   11 months ago
#
#                                           Review Text  \
# 0   Big campus so walking to classes can take long...
# 1   Despite being in the heart of one of the busie...
# 2   January 2021 walk around the grounds at U of T...
# 3   A magnificent and charming campus in the heart...
# 4   Amazing tour of the university! 👌🏼👌🏼 Check out...
# ..                                                ...
# 95                         Best University for my son
# 96                       Beautiful university campus.
# 97  The University of Toronto (U of T or UToronto)...
# 98  Very competitive. Appreciated for the multi-cu...
# 99  The building is nice but the application proce...
#
#                        User                     Impact
# 0              Ashley Tapp    Local Guide · 41 reviews
# 1             Samuel Leung   Local Guide · 303 reviews
# 2    Tim Chase Photography   Local Guide · 471 reviews
# 3     Guilherme Cavalcante   Local Guide · 360 reviews
# 4             Fouad Abboud    Local Guide · 50 reviews
# ..                      ...                        ...
# 95             Tung Nguyen   Local Guide · 115 reviews
# 96           Lorne Haveruk   Local Guide · 177 reviews
# 97            Malik Nadeem      Local Guide903 reviews
# 98                  A Chan        Local Guide9 reviews
# 99           Tristan Lopez       Local Guide15 reviews
#
# [100 rows x 5 columns]

# %% [markdown]
# # data cleaning

# %%
rev_summ['Impact'] = rev_summ['Impact'].map(lambda x: x.lstrip('Local Guide ·'))

# %%
rev_summ
# Out:
#    Review Rate    Review Time  \
# 0     4 stars     a month ago
# 1     5 stars    7 months ago
# 2     5 stars    9 months ago
# 3     5 stars     3 weeks ago
# 4     5 stars    3 months ago
# ..         ...            ...
# 95    5 stars    2 months ago
# 96    5 stars      a year ago
# 97    5 stars      a year ago
# 98    3 stars      a year ago
# 99    2 stars   11 months ago
#
#                                           Review Text  \
# 0   Big campus walking classes take long  I wish f...
# 1   Despite heart one busiest cities world  St Geo...
# 2   January 2021 walk around grounds U T taking ma...
# 3        A magnificent charming campus heart Toronto
# 4        Amazing tour university       Check photos
# ..                                                ...
# 95                                Best University son
# 96                       Beautiful university campus
# 97  The University Toronto  U T UToronto  public r...
# 98  Very competitive  Appreciated multi cultural b...
# 99  The building nice application process far comp...
#
#                        User       Impact
# 0              Ashley Tapp    41 reviews
# 1             Samuel Leung   303 reviews
# 2    Tim Chase Photography   471 reviews
# 3     Guilherme Cavalcante   360 reviews
# 4             Fouad Abboud    50 reviews
# ..                      ...          ...
# 95             Tung Nguyen   115 reviews
# 96           Lorne Haveruk   177 reviews
# 97            Malik Nadeem   903 reviews
# 98                  A Chan     9 reviews
# 99           Tristan Lopez    15 reviews
#
# [100 rows x 5 columns]

# %% [markdown]
# # list stopwords

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fatih\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# # cleaning stopwords

# %%
stop = stopwords.words('english')
rev_summ['Review Text'] = rev_summ['Review Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
rev_summ
# Out:
#    Review Rate    Review Time  \
# 0     4 stars     a month ago
# 1     5 stars    7 months ago
# 2     5 stars    9 months ago
# 3     5 stars     3 weeks ago
# 4     5 stars    3 months ago
# ..         ...            ...
# 95    5 stars    2 months ago
# 96    5 stars      a year ago
# 97    5 stars      a year ago
# 98    3 stars      a year ago
# 99    2 stars   11 months ago
#
#                                           Review Text  \
# 0   Big campus walking classes take long I wish fo...
# 1   Despite heart one busiest cities world St Geor...
# 2   January 2021 walk around grounds U T taking ma...
# 3         A magnificent charming campus heart Toronto
# 4                Amazing tour university Check photos
# ..                                                ...
# 95                                Best University son
# 96                        Beautiful university campus
# 97  The University Toronto U T UToronto public res...
# 98  Very competitive Appreciated multi cultural ba...
# 99  The building nice application process far comp...
#
#                        User       Impact
# 0              Ashley Tapp    41 reviews
# 1             Samuel Leung   303 reviews
# 2    Tim Chase Photography   471 reviews
# 3     Guilherme Cavalcante   360 reviews
# 4             Fouad Abboud    50 reviews
# ..                      ...          ...
# 95             Tung Nguyen   115 reviews
# 96           Lorne Haveruk   177 reviews
# 97            Malik Nadeem   903 reviews
# 98                  A Chan     9 reviews
# 99           Tristan Lopez    15 reviews
#
# [100 rows x 5 columns]

# %% [markdown]
# # print full description

# %%
description_full = rev_summ.set_index('Review Text')
description_full.head(5)
# Out:
#                                                    Review Rate   Review Time  \
# Review Text
# Big campus walking classes take long I wish foo...    4 stars    a month ago
# Despite heart one busiest cities world St Georg...    5 stars   7 months ago
# January 2021 walk around grounds U T taking mag...    5 stars   9 months ago
# A magnificent charming campus heart Toronto           5 stars    3 weeks ago
# Amazing tour university Check photos                  5 stars   3 months ago
#
#                                                                        User  \
# Review Text
# Big campus walking classes take long I wish foo...             Ashley Tapp
# Despite heart one busiest cities world St Georg...            Samuel Leung
# January 2021 walk around grounds U T taking mag...   Tim Chase Photography
# A magnificent charming campus heart Toronto           Guilherme Cavalcante
# Amazing tour university Check photos                          Fouad Abboud
#
#                                                          Impact
# Review Text
# Big campus walking classes take long I wish foo...   41 reviews
# Despite heart one busiest cities world St Georg...  303 reviews
# January 2021 walk around grounds U T taking mag...  471 reviews
# A magnificent charming campus heart Toronto         360 reviews
# Amazing tour university Check photos                 50 reviews

# %% [markdown]
# # remove ponctuation

# %%
rev_summ['Review Text'] = rev_summ['Review Text'].str.replace('[^\w\s]',' ')
rev_summ
# Out:
# <ipython-input-24-3283235791aa>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   rev_summ['Review Text'] = rev_summ['Review Text'].str.replace('[^\w\s]',' ')
#    Review Rate    Review Time  \
# 0     4 stars     a month ago
# 1     5 stars    7 months ago
# 2     5 stars    9 months ago
# 3     5 stars     3 weeks ago
# 4     5 stars    3 months ago
# ..         ...            ...
# 95    5 stars    2 months ago
# 96    5 stars      a year ago
# 97    5 stars      a year ago
# 98    3 stars      a year ago
# 99    2 stars   11 months ago
#
#                                           Review Text  \
# 0   Big campus walking classes take long I wish fo...
# 1   Despite heart one busiest cities world St Geor...
# 2   January 2021 walk around grounds U T taking ma...
# 3         A magnificent charming campus heart Toronto
# 4                Amazing tour university Check photos
# ..                                                ...
# 95                                Best University son
# 96                        Beautiful university campus
# 97  The University Toronto U T UToronto public res...
# 98  Very competitive Appreciated multi cultural ba...
# 99  The building nice application process far comp...
#
#                        User       Impact
# 0              Ashley Tapp    41 reviews
# 1             Samuel Leung   303 reviews
# 2    Tim Chase Photography   471 reviews
# 3     Guilherme Cavalcante   360 reviews
# 4             Fouad Abboud    50 reviews
# ..                      ...          ...
# 95             Tung Nguyen   115 reviews
# 96           Lorne Haveruk   177 reviews
# 97            Malik Nadeem   903 reviews
# 98                  A Chan     9 reviews
# 99           Tristan Lopez    15 reviews
#
# [100 rows x 5 columns]

# %%
rev_summ.to_csv("reviews_UoT_video2.csv")
